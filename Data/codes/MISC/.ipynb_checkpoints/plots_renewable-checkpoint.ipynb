# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter
import matplotlib.font_manager as fm
import palettable
plot_root = '../../plots/renewable'

# %%
df1 = pd.read_csv('../../output_renewable/ces0_90_85_higheps.csv')
df2 = pd.read_csv('../../output_sig0/ces0.csv')
df3 = pd.read_csv('../../output_renewable/ces0_90_85.csv')
df4 = pd.read_csv('../../output_renewable/ces0_80_85.csv')
df5 = pd.read_csv('../../output_sig0/ces0.csv')

# %%
df1 = df1[df1['region_scenario'] == 3]
df2 = df2[(df2['region_scenario'] == 3) & (df2['tax_sce']=='Unilateral')]
df5 = df5[(df2['region_scenario'] == 3) & (df5['tax_sce']=='Unilateral')]
df5
# Out:
#      Unnamed: 0     tax_sce      regionbase  varphi        pe        tb  \
# 200           2  Unilateral  OECD37 as Home     0.0  1.000000  0.000000
# 201           8  Unilateral  OECD37 as Home     0.1  0.993667  0.039978
# 202          14  Unilateral  OECD37 as Home     0.2  0.988370  0.079571
# 203          20  Unilateral  OECD37 as Home     0.3  0.984048  0.118885
# 204          26  Unilateral  OECD37 as Home     0.4  0.980651  0.158020
# ..          ...         ...             ...     ...       ...       ...
# 295         572  Unilateral  OECD37 as Home     9.5  0.884699  3.541687
# 296         578  Unilateral  OECD37 as Home     9.6  0.883382  3.576521
# 297         584  Unilateral  OECD37 as Home     9.7  0.882071  3.611345
# 298         590  Unilateral  OECD37 as Home     9.8  0.880766  3.646161
# 299         596  Unilateral  OECD37 as Home     9.9  0.879467  3.680969
#
#          prop   te  jxbar_prime  jmbar_prime  ...  chg_extraction  \
# 200  0.399993  0.0     0.049234     0.819498  ...   -3.552714e-15
# 201  0.546249  0.1     0.049253     0.819498  ...   -7.501163e-02
# 202  0.152696  0.2     0.049307     0.819498  ...   -1.379314e-01
# 203  0.101375  0.3     0.049394     0.819498  ...   -1.893988e-01
# 204  0.076535  0.4     0.049510     0.819498  ...   -2.299196e-01
# ..        ...  ...          ...          ...  ...             ...
# 295  0.036574  9.5     0.114508     0.819498  ...   -1.405211e+00
# 296  0.037264  9.6     0.115686     0.819498  ...   -1.421771e+00
# 297  0.037962  9.7     0.116874     0.819498  ...   -1.438269e+00
# 298  0.038752  9.8     0.118073     0.819498  ...   -1.454707e+00
# 299  0.039524  9.9     0.119283     0.819498  ...   -1.471090e+00
#
#      chg_production  chg_consumption   chg_Qeworld         pai_g  \
# 200        0.000000     3.552714e-15 -7.105427e-15  2.664535e-15
# 201        0.030757     8.248339e-02 -3.660947e-01 -2.042418e-01
# 202        0.047295     1.491139e-01 -7.276268e-01 -4.124324e-01
# 203        0.049903     2.002534e-01 -1.085890e+00 -6.248467e-01
# 204        0.038785     2.361805e-01 -1.442145e+00 -8.418016e-01
# ..              ...              ...           ...           ...
# 295       -0.998404     6.370864e-01 -1.003070e+01 -2.079976e+01
# 296       -0.999693     6.439230e-01 -1.004726e+01 -2.100322e+01
# 297       -1.001259     6.504726e-01 -1.006376e+01 -2.120667e+01
# 298       -1.003099     6.567381e-01 -1.008020e+01 -2.141010e+01
# 299       -1.005213     6.627235e-01 -1.009658e+01 -2.161351e+01
#
#      subsidy_ratio       welfare  welfare_noexternality  region_scenario  conv
# 200       0.000000  1.936790e-14           1.936790e-14              3.0   1.0
# 201       0.005999  1.997046e-02          -1.987669e-02              3.0   1.0
# 202       0.011932  7.952943e-02          -7.886598e-02              3.0   1.0
# 203       0.017799  1.782464e-01          -1.763311e-01              3.0   1.0
# 204       0.023600  3.158398e-01          -3.120348e-01              3.0   1.0
# ..             ...           ...                    ...              ...   ...
# 295       0.375191  8.352406e+01          -2.019506e+01              3.0   1.0
# 296       0.377839  8.461688e+01          -2.036706e+01              3.0   1.0
# 297       0.380469  8.571150e+01          -2.054020e+01              3.0   1.0
# 298       0.383083  8.680792e+01          -2.071450e+01              3.0   1.0
# 299       0.385681  8.790613e+01          -2.088999e+01              3.0   1.0
#
# [100 rows x 49 columns]

# %%
plt.plot(df1['varphi'],df1['Ceystar_prime'],linewidth=1, label = 'Ceystar_prime')
plt.plot(df1['varphi'],df1['Cey_prime'],linewidth=1, label = 'Cey_prime')
plt.plot(df1['varphi'],df1['Cex_prime'],linewidth=1, label = 'Cex_prime')
plt.plot(df1['varphi'],df1['Cem_prime'],linewidth=1, label = 'Cem_prime')
plt.legend()

# %%
plt.plot(df1['varphi'],df1['Qe1_prime'],linewidth=1, label = 'Qe1')
plt.plot(df1['varphi'],df1['Qe2_prime'],linewidth=1, label = 'Qe2_prime')
plt.plot(df1['varphi'],df1['Qe1star_prime'],linewidth=1, label = 'Qe1star')
plt.plot(df1['varphi'],df1['Qe2star_prime'],linewidth=1, label = 'Qe2star_prime')
plt.legend()

# %%
plt.plot(df1['varphi'],df1['jxbar_prime'],linewidth=1, label = 'jxbar_prime')
plt.plot(df1['varphi'],df1['j0_prime'],linewidth=1, label = 'j0_prime')
plt.legend()

# %%
df_plot = df1
plt.plot(df_plot['varphi'],df_plot['Ge_prime'],linewidth=1, label = 'Ge_prime')
plt.plot(df_plot['varphi'],df_plot['Gestar_prime'],linewidth=1, label = 'Gestar_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2_prime'],linewidth=1, label = 'Qe2_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2star_prime'],linewidth=1, label = 'Qe2star_prime')
plt.legend()

plt.xlabel('varphi')
plt.ylabel('Energy')
plt.savefig(plot_root + '/varphi_ge_higheps.pdf',format='pdf', bbox_inches = 'tight')

# %%
df_plot = df4
plt.plot(df_plot['varphi'],df_plot['Ge_prime'],linewidth=1, label = 'Ge_prime')
plt.plot(df_plot['varphi'],df_plot['Gestar_prime'],linewidth=1, label = 'Gestar_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2_prime'],linewidth=1, label = 'Qe2_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2star_prime'],linewidth=1, label = 'Qe2star_prime')
plt.legend()

plt.xlabel('varphi')
plt.ylabel('Energy')
plt.savefig(plot_root + '/varphi_ge.pdf',format='pdf', bbox_inches = 'tight')

# %%
plt.xlim(-10,0)
x = 'welfare_noexternality'
y = 'Qeworld_chg'
df_plot=df1[df1['varphi'] <= 4.5]
df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'Higher elasticity of renewable energy')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

df_plot=df2
df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'No renewable energy')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

df_plot=df3
df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'With renewable energy')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

df_plot=df4[df4['varphi'] < 9]
df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'Higher initial share of renewable')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

plt.legend()
ylab = 'Global emissions reductions (% of BAU)'
xlab = 'Change in total consumption \n(% of initial goods consumption)'
plt.xlabel(xlab)
plt.ylabel(ylab)

plt.savefig(plot_root + '/fig4.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_22524/173918290.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_22524/173918290.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100

# %%
df_plot = df3[df3['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Home')
plt.plot(df_plot['varphi'], df_plot['prop_energy_star'], label= 'Foreign')

df_plot = df1[df1['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Home (high eps)')
plt.plot(df_plot['varphi'], df_plot['prop_energy_star'], label= 'Foreign (high eps)')

df_plot = df4[df4['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Home (Home high initial)')
plt.plot(df_plot['varphi'], df_plot['prop_energy_star'], label= 'Foreign (Home high initial)')

ylab = 'Renewable energy extraction (fraction of total extraction)'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/home_prop.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3806290871.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3806290871.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3806290871.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3806290871.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3806290871.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3806290871.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100

# %%
df_plot = df3[df3['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
#plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Home')
plt.plot(df_plot['varphi'], df_plot['prop_energy_star'], label= 'Foreign')

df_plot = df1[df1['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
#plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Home (high eps)')
plt.plot(df_plot['varphi'], df_plot['prop_energy_star'], label= 'Foreign (high eps)')

df_plot = df4[df4['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'] * 100
#plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Home (high initial)')
plt.plot(df_plot['varphi'], df_plot['prop_energy_star'], label= 'Foreign (high initial)')

ylab = 'Renewable energy extraction (% of total extraction)'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/foreign_prop.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3169938917.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3169938917.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3169938917.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3169938917.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3169938917.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/3169938917.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'] * 100

# %%
x = 'varphi'

df_plot = df3[df3['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home')
#plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign')

df_plot = df1[df1['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high eps)')
#plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high eps)')

df_plot = df4[df4['varphi'] <= 4.5]
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high initial)')
#plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high initial)')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
#plt.xlim(-10,0)
#plt.ylim(0,0.5)
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()

plt.savefig(plot_root + '/home_prop_initial.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/313811582.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/313811582.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/313811582.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100

# %%
x = 'varphi'

df_plot = df3[df3['varphi'] <= 4.5]
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home')
plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign')

df_plot = df1[df1['varphi'] <= 4.5]
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high eps)')
plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high eps)')

df_plot = df4[df4['varphi'] <= 4.5]
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high initial)')
plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high initial)')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
#plt.xlim(-10,0)
#plt.ylim(0,0.5)
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/foreign_prop_initial.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/2460972969.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/2460972969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/2460972969.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100

# %%
x = 'varphi'

df_plot = df3[df3['varphi'] <= 4.5]
plt.plot(df_plot[x], df_plot['Qe1_prime'], label= 'Qe1_prime')

df_plot = df1[df1['varphi'] <= 4.5]
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high eps)')
plt.plot(df_plot[x], df_plot['Qe1_prime'], label ='Qe1_prime (high eps)')

df_plot = df4[df4['varphi'] <= 4.5]
plt.plot(df_plot[x], df_plot['Qe1_prime'], label= 'Qe1_prime (high initial)')

df_plot = df5[df5['varphi'] <= 4.5]
plt.plot(df_plot[x], df_plot['Qe_prime'], label= 'Qe1_prime (No renewable)')

ylab = 'Energy extraction'
xlab = 'varphi'
#plt.xlim(-10,0)
#plt.ylim(0,0.5)
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/varphi_qe.pdf', format='pdf', bbox_inches = 'tight')
