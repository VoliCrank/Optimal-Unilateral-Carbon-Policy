# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter
import matplotlib.font_manager as fm
import palettable
plot_root = '../../plots/renewable'

# %%
mpl.__version__
mpl.rcParams.update({'font.size': 7})
mpl.rcParams['axes.grid'] = True
mpl.rcParams.update({'axes.grid.axis':'y','grid.color':'#949494','grid.linewidth':0.2})
plt.locator_params(axis='y', nbins=5)   # y-axis

# %%
df1 = pd.read_csv('../../output_renewable/all0_90_85.csv')
df2 = pd.read_csv('../../output_sig0/ces0.csv')

# %%
df1 = df1[df1['region_scenario'] == 3]
df2 = df2[(df2['region_scenario'] == 3)]
df1['Qe1world_prime'] = df1['Qe1_prime'] + df1['Qe1star_prime']

# %%
plt.plot(df1['varphi'],df1['Ceystar_prime'],linewidth=1, label = 'Ceystar_prime')
plt.plot(df1['varphi'],df1['Cey_prime'],linewidth=1, label = 'Cey_prime')
plt.plot(df1['varphi'],df1['Cex_prime'],linewidth=1, label = 'Cex_prime')
plt.plot(df1['varphi'],df1['Cem_prime'],linewidth=1, label = 'Cem_prime')
plt.legend()

# %%
plt.plot(df1['varphi'],df1['Qe2_prime'],linewidth=1, label = 'Qe2_prime')
plt.plot(df1['varphi'],df1['Ge_prime'],linewidth=1, label = 'Ge_prime')
plt.legend()
plt.savefig(plot_root + '/all_qe_ge.pdf',format='pdf', bbox_inches = 'tight')

# %%
plt.plot(df1['varphi'],df1['jxbar_prime'],linewidth=1, label = 'jxbar_prime')
plt.plot(df1['varphi'],df1['j0_prime'],linewidth=1, label = 'j0_prime')
plt.legend()

# %%
df_plot = df1[df1['tax_sce'] == 'puretp']
plt.plot(df_plot['varphi'],df_plot['Ge_prime'],linewidth=1, label = 'Ge_prime')
plt.plot(df_plot['varphi'],df_plot['Gestar_prime'],linewidth=1, label = 'Gestar_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2_prime'],linewidth=1, label = 'Qe2_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2star_prime'],linewidth=1, label = 'Qe2star_prime')
plt.legend()

plt.xlabel('varphi')
plt.ylabel('Energy')
#plt.savefig(plot_root + '/varphi_ge_higheps.pdf',format='pdf', bbox_inches = 'tight')

# %%
df_plot = df4
plt.plot(df_plot['varphi'],df_plot['Ge_prime'],linewidth=1, label = 'Ge_prime')
plt.plot(df_plot['varphi'],df_plot['Gestar_prime'],linewidth=1, label = 'Gestar_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2_prime'],linewidth=1, label = 'Qe2_prime')
plt.plot(df_plot['varphi'],df_plot['Qe2star_prime'],linewidth=1, label = 'Qe2star_prime')
plt.legend()

plt.xlabel('varphi')
plt.ylabel('Energy')
#plt.savefig(plot_root + '/varphi_ge.pdf',format='pdf', bbox_inches = 'tight')

# %%
plt.xlim(-10,0)
x = 'welfare_noexternality'
y = 'Qeworld_chg'
df_plot=df1[df1['tax_sce'] == 'Unilateral']
df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'Higher elasticity of renewable energy')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

df_plot=df2
df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'No renewable energy')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

df_plot=df3
df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'With renewable energy')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

df_plot=df4[df4['varphi'] < 9]
df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
plt.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'Higher initial share of renewable')
dot=df_plot[df_plot['varphi']==2] #puretp
plt.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

plt.legend()
ylab = 'Global emissions reductions (% of BAU)'
xlab = 'Change in total consumption \n(% of initial goods consumption)'
plt.xlabel(xlab)
plt.ylabel(ylab)

#plt.savefig(plot_root + '/fig4.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_22524/173918290.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_22524/173918290.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1_prime'] + df_plot['Qe1star_prime'] -df_plot['Qe1_prime'].iat[0]-df_plot['Qe1star_prime'].iat[0]) / (df_plot['Qe1_prime'].iat[0]+df_plot['Qe1star_prime'].iat[0]) * 100

# %%
df_plot = df1[df1['tax_sce'] == 'Unilateral']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Unilateral')

df_plot = df1[df1['tax_sce'] == 'purete']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'pure te')

df_plot = df1[df1['tax_sce'] == 'puretc']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'pure tc')

df_plot = df1[df1['tax_sce'] == 'puretp']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'puretp')

ylab = 'Renewable energy extraction (% of total extraction)'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/basic_prop.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime']* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/369355694.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime']* 100

# %%
df1['prop_energy'] = df1['Qe2_prime'] / df1['Qe_prime'].iat[0] * 100

df_plot = df1[df1['tax_sce'] == 'Unilateral']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Unilateral')

df_plot = df1[df1['tax_sce'] == 'purete']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'purete')

df_plot = df1[df1['tax_sce'] == 'puretc']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'puretc')

df_plot = df1[df1['tax_sce'] == 'puretp']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'puretp')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/basic_prop_init.pdf', format='pdf', bbox_inches = 'tight')

# %%
df1['prop_energy'] = df1['Qe2star_prime'] / df1['Qestar_prime'].iat[0] * 100

df_plot = df1[df1['tax_sce'] == 'Unilateral']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Unilateral')

df_plot = df1[df1['tax_sce'] == 'purete']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'pure te')

df_plot = df1[df1['tax_sce'] == 'puretc']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'pure tc')

df_plot = df1[df1['tax_sce'] == 'puretp']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'puretp')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/basic_prop_init_foreign.pdf', format='pdf', bbox_inches = 'tight')

# %%
x = 'varphi'
y = 'Qe_prime'
df1['prop_energy'] = df1['Qe2star_prime'] / df1['Qestar_prime'].iat[0] * 100

df_plot = df1[df1['tax_sce'] == 'Unilateral']
plt.plot(df_plot[x], df_plot[y], label = 'Unilateral')

df_plot = df1[df1['tax_sce'] == 'purete']
plt.plot(df_plot[x], df_plot[y], label = 'pure te')

df_plot = df1[df1['tax_sce'] == 'puretc']
plt.plot(df_plot[x], df_plot[y], label = 'pure tc')

df_plot = df1[df1['tax_sce'] == 'puretp']
plt.plot(df_plot[x], df_plot[y], label = 'puretp')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
#plt.savefig(plot_root + '/basic_prop_init_foreign.pdf', format='pdf', bbox_inches = 'tight')

# %%
x = 'varphi'
y = 'pe'

df_plot = df2[df2['tax_sce'] == 'Unilateral']
plt.plot(df_plot[x], df_plot[y], label = 'Unilateral')

df_plot = df2[df2['tax_sce'] == 'purete']
plt.plot(df_plot[x], df_plot[y], label = 'purete')

df_plot = df2[df2['tax_sce'] == 'puretc']
plt.plot(df_plot[x], df_plot[y], label = 'puretc')

df_plot = df2[df2['tax_sce'] == 'puretp']
plt.plot(df_plot[x], df_plot[y], label = 'puretp')

ylab = 'price of energy'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/varphi_pe.pdf', format='pdf', bbox_inches = 'tight')

# %%
x = 'varphi'
y = 'te'

df_plot = df2[df2['tax_sce'] == 'Unilateral']
plt.plot(df_plot[x], df_plot[y], label = 'Unilateral')

df_plot = df2[df2['tax_sce'] == 'purete']
plt.plot(df_plot[x], df_plot[y], label = 'purete')

df_plot = df2[df2['tax_sce'] == 'puretc']
plt.plot(df_plot[x], df_plot[y], label = 'puretc')

df_plot = df2[df2['tax_sce'] == 'puretp']
plt.plot(df_plot[x], df_plot[y], label = 'puretp')

ylab = 'price of energy'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()

# %%
x = 'varphi'
y = 'tb'

df_plot = df2[df2['tax_sce'] == 'Unilateral']
plt.plot(df_plot[x], df_plot[y], label = 'Unilateral')

df_plot = df2[df2['tax_sce'] == 'purete']
plt.plot(df_plot[x], df_plot[y], label = 'purete')

df_plot = df2[df2['tax_sce'] == 'puretc']
plt.plot(df_plot[x], df_plot[y], label = 'puretc')

df_plot = df2[df2['tax_sce'] == 'puretp']
plt.plot(df_plot[x], df_plot[y], label = 'puretp')

ylab = 'tb'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/varphi_tb.pdf', format='pdf', bbox_inches = 'tight')

# %%
df1['prop_energy'] = df1['Qe2star_prime'] / df1['Qestar_prime'] * 100

df_plot = df1[df1['tax_sce'] == 'Unilateral']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'Unilateral')

df_plot = df1[df1['tax_sce'] == 'purete']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'pure te')

df_plot = df1[df1['tax_sce'] == 'puretc']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'pure tc')

df_plot = df1[df1['tax_sce'] == 'puretp']
plt.plot(df_plot['varphi'], df_plot['prop_energy'], label = 'puretp')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/basic_prop_foreign.pdf', format='pdf', bbox_inches = 'tight')

# %%
x = 'varphi'
df1['prop_energy'] = df1['Qe2_prime'] / df1['Qe_prime'] * 100
fig, (ax1) = plt.subplots(1, 1)
#ax2.plot(df4['welfare_noexternality'], df4['Qeworld_chg'], linestyle = 'solid', label = 'global planner', color = "purple")

plot_tax(fig, [df1], xlow = 0, xhigh =10, ylow=10, yhigh = 101, varphi = 10, y = 'prop_energy', x = 'varphi')
ylab = 'Renewable energy extraction (% of total extraction)'
xlab = 'varphi'
#ylab = 'Global emissions reduction (% of BAU)'
#xlab = 'varphi'
ax1.set_ylabel(ylab)
ax1.set_xlabel(xlab)
ax1.set_title(r"$\rho = 0$", fontsize=6)


plt.legend(loc = 'upper left', bbox_to_anchor=(-0.1, -0.15),fancybox=True, ncol = 4, shadow=False,frameon=False)
plt.savefig(plot_root + '/all_prop.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opt['Qeworld_chg']=-(df_opt['Qe1world_prime']-df_opt['Qe1world_prime'].iat[0]) / df_opt['Qe1world_prime'].iat[0]
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:24: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/ df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:32: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:40: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:48: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:56: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:64: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:72: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:80: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])

# %%
x = 'varphi'
df1['prop_energy'] = df1['Qe2_prime'] / df1['Qe_prime'].iat[0] * 100
fig, (ax1) = plt.subplots(1, 1)
#ax2.plot(df4['welfare_noexternality'], df4['Qeworld_chg'], linestyle = 'solid', label = 'global planner', color = "purple")

plot_tax(fig, [df1], xlow = 0, xhigh =10, ylow=10, yhigh = 20, varphi = 10, y = 'prop_energy', x = 'varphi')
ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
#ylab = 'Global emissions reduction (% of BAU)'
#xlab = 'varphi'
ax1.set_ylabel(ylab)
ax1.set_xlabel(xlab)
ax1.set_title(r"$\rho = 0$", fontsize=6)


plt.legend(loc = 'upper left', bbox_to_anchor=(-0.1, -0.15),fancybox=True, ncol = 4, shadow=False,frameon=False)
plt.savefig(plot_root + '/all_prop_initial.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opt['Qeworld_chg']=-(df_opt['Qe1world_prime']-df_opt['Qe1world_prime'].iat[0]) / df_opt['Qe1world_prime'].iat[0]
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:24: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/ df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:32: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:40: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:48: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:56: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:64: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:72: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:80: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])

# %%
x = 'varphi'
df1['prop_energy'] = df1['Qe2star_prime'] / df1['Qestar_prime'].iat[0] * 100
fig, (ax1) = plt.subplots(1, 1)
#ax2.plot(df4['welfare_noexternality'], df4['Qeworld_chg'], linestyle = 'solid', label = 'global planner', color = "purple")

plot_tax(fig, [df1], xlow = 0, xhigh =10, ylow=10, yhigh = 20, varphi = 10, y = 'prop_energy', x = 'varphi')
ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
#ylab = 'Global emissions reduction (% of BAU)'
#xlab = 'varphi'
ax1.set_ylabel(ylab)
ax1.set_xlabel(xlab)
ax1.set_title(r"$\rho = 0$", fontsize=6)


plt.legend(loc = 'upper left', bbox_to_anchor=(-0.1, -0.15),fancybox=True, ncol = 4, shadow=False,frameon=False)
plt.savefig(plot_root + '/all_prop_initial_foreign.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opt['Qeworld_chg']=-(df_opt['Qe1world_prime']-df_opt['Qe1world_prime'].iat[0]) / df_opt['Qe1world_prime'].iat[0]
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:24: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/ df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:32: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:40: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:48: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:56: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:64: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:72: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:80: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/1131081339.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])

# %%
x = 'varphi'

df_plot = df1[df1['tax_sce'] == 'Unilateral']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Unilateral')
#plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign')

df_plot = df1[df1['tax_sce'] == 'purete']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
plt.plot(df_plot[x], df_plot['prop_energy'], label = 'purete')
#plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high eps)')

df_plot = df1[df1['tax_sce'] == 'puretc']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
plt.plot(df_plot[x], df_plot['prop_energy'], label = 'puretc')
#plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high initial)')

df_plot = df1[df1['tax_sce'] == 'puretp']
df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
plt.plot(df_plot[x], df_plot['prop_energy'], label = 'puretp')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
#plt.xlim(-10,0)
#plt.ylim(0,0.5)
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
plt.savefig(plot_root + '/basic_prop_initial.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/2153935788.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/2153935788.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/2153935788.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/2153935788.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy'] = df_plot['Qe2_prime'] / df_plot['Qe_prime'].iat[0]* 100

# %%
x = 'varphi'

df_plot = df3[df3['varphi'] <= 4.5]
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home')
plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign')

df_plot = df1[df1['varphi'] <= 4.5]
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high eps)')
plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high eps)')

df_plot = df4[df4['varphi'] <= 4.5]
df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high initial)')
plt.plot(df_plot[x], df_plot['prop_energy_star'], label= 'Foreign (high initial)')

ylab = 'Renewable energy extraction (% of initial extraction)'
xlab = 'varphi'
#plt.xlim(-10,0)
#plt.ylim(0,0.5)
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
#plt.savefig(plot_root + '/foreign_prop_initial.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/2460972969.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/2460972969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_12420/2460972969.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['prop_energy_star'] = df_plot['Qe2star_prime'] / df_plot['Qestar_prime'].iat[0]* 100

# %%
x = 'varphi'

df_plot = df1[df1['tax_sce']== 'Unilateral']
plt.plot(df_plot[x], df_plot['Qe1_prime'], label= 'Unilateral')

df_plot = df1[df1['tax_sce']== 'purete']
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high eps)')
plt.plot(df_plot[x], df_plot['Qe1_prime'], label ='purete')

df_plot = df1[df1['tax_sce']== 'puretc']
plt.plot(df_plot[x], df_plot['Qe1_prime'], label= 'puretc')

df_plot = df1[df1['tax_sce']== 'puretp']
plt.plot(df_plot[x], df_plot['Qe1_prime'], label= 'puretp')

ylab = 'Energy extraction'
xlab = 'varphi'
#plt.xlim(-10,0)
#plt.ylim(0,0.5)
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()
#plt.savefig(plot_root + '/varphi_qe.pdf', format='pdf', bbox_inches = 'tight')

# %%
x = 'varphi'

df_plot = df1[df1['tax_sce']== 'Unilateral']
plt.plot(df_plot[x], df_plot['Qe2_prime'], label= 'Unilateral')

df_plot = df1[df1['tax_sce']== 'purete']
#plt.plot(df_plot[x], df_plot['prop_energy'], label = 'Home (high eps)')
plt.plot(df_plot[x], df_plot['Qe2_prime'], label ='purete')

df_plot = df1[df1['tax_sce']== 'puretc']
plt.plot(df_plot[x], df_plot['Qe2_prime'], label= 'puretc')

df_plot = df1[df1['tax_sce']== 'puretp']
plt.plot(df_plot[x], df_plot['Qe2_prime'], label= 'puretp')

df_plot = df1[df1['tax_sce']== 'EPC_hybrid']
#plt.plot(df_plot[x], df_plot['Qe2_prime'], label= 'EPC_hybrid')

ylab = 'Energy extraction'
xlab = 'varphi'
#plt.xlim(-10,0)
#plt.ylim(0,0.5)
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.legend()

# %%
def plot_tax(fig, lodf, xlow = -35, xhigh = 0, ylow = 0, yhigh = 40, varphi = 20, x = 'welfare_noexternality', y = 'Qeworld_chg'):
    i=0
    for ax in fig.get_axes():
        ax.set_xlim(xlow,xhigh)
        ax.set_ylim(ylow,yhigh)
        ax.spines["top"].set_visible(False)    
        ax.spines["bottom"].set_visible(True)    
        ax.spines["right"].set_visible(False)    
        ax.spines["left"].set_visible(False)
        
        df = lodf[i]
        i += 1

        df = df[df['varphi'] <= varphi]
        df_opt = df[(df['tax_sce']=='Unilateral') & (df['region_scenario']==3)] 
        df_opt['Qeworld_chg']=-(df_opt['Qe1world_prime']-df_opt['Qe1world_prime'].iat[0]) / df_opt['Qe1world_prime'].iat[0]
        #df['Qeworld_chg']=-(df['Qeworld_prime']-Qeworld)/Qeworld*100
        #x = 'varphi'
        #y = 'ratio'

        ##puretp
        df_plot=df[(df['tax_sce']=='puretp') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l1, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed',dashes = (5,1), label = 'production tax')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##purete
        df_plot=df[(df['tax_sce']=='purete') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/ df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l2, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed',dashes = (8,1), label = 'extraction tax')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##puretc
        df_plot=df[(df['tax_sce']=='puretc') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l3, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed',dashes = (5,3), label = 'consumption tax')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##production/consumption
        df_plot=df[(df['tax_sce']=='PC_hybrid') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l4, = ax.plot(df_plot[x],df_plot[y],linestyle='dotted', label = 'production-consumption')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##extracion/production
        df_plot=df[(df['tax_sce']=='EP_hybrid')  & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l5, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed', label = 'extraction-production')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        # #extraction/consumption
        df_plot=df[(df['tax_sce']=='EC_hybrid') & (df['region_scenario']==3)]
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l6, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed',dashes = (3,1), label = 'extraction-consumption')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        # #extraction/consumption/production
        df_plot=df[(df['tax_sce']=='EPC_hybrid') & (df['region_scenario']==3)]
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l8, = ax.plot(df_plot[x],df_plot[y],linestyle='dashdot', label = 'extraction-cons-prod')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##unilateral optimal
        df_plot=df[(df['tax_sce']=='Unilateral') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l7, = ax.plot(df_plot[x],df_plot[y],linestyle='dotted', label = 'unilateral optimal')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red')

# %%
fig, (ax1) = plt.subplots(1, 1)
#ax2.plot(df4['welfare_noexternality'], df4['Qeworld_chg'], linestyle = 'solid', label = 'global planner', color = "purple")

plot_tax(fig, [df1], xlow = -10, xhigh =0, yhigh = 30, varphi = 20)
ylab = 'Global emissions reductions (% of BAU)'
xlab = 'Change in total consumption \n(% of initial goods consumption)'
#ylab = 'Global emissions reduction (% of BAU)'
#xlab = 'varphi'
ax1.set_ylabel(ylab)
ax1.set_xlabel(xlab)
ax1.set_title(r"$\rho = 0$", fontsize=6)


plt.legend(loc = 'upper left', bbox_to_anchor=(-0.1, -0.15),fancybox=True, ncol = 4, shadow=False,frameon=False)
plt.savefig(plot_root + '/all_fig4.pdf', format='pdf', bbox_inches = 'tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opt['Qeworld_chg']=-(df_opt['Qe1world_prime']-df_opt['Qe1world_prime'].iat[0]) / df_opt['Qe1world_prime'].iat[0]
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:24: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0])/ df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:32: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:40: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:48: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:56: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:64: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:72: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qe1world_prime']-df_plot['Qe1world_prime'].iat[0]) / df_plot['Qe1world_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:80: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_9448/175341872.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
