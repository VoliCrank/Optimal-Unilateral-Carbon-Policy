# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter
import matplotlib.font_manager as fm
import palettable

# %%
mpl.__version__
mpl.rcParams.update({'font.size':12})
mpl.rcParams['axes.grid'] = True
mpl.rcParams.update({'axes.grid.axis':'y','grid.color':'#949494','grid.linewidth':0.2})
plt.locator_params(axis='y', nbins=5)   # y-axis
# plt.rcParams["font.family"] = "DejaVu Sans"
mpl.rcParams["font.family"] = "Linux Libertine"
# fontpath = "/Users/bellayao/Library/Fonts/LinLibertine_R.ttf" #For Bella's local
# prop = fm.FontProperties(fname=fontpath)
# plt.rcParams['font.family'] = prop.get_name()
plt.rcParams['lines.linewidth']=1.25

# %%
fig, (ax)=plt.subplots()
ax.set_xlim(-9,0)
ax.set_ylim(0,60)
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(True)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)
ax.set_xlabel('Change in total consumption \n(% of initial goods consumption)')

num_plots = 5
colormap = plt.cm.binary
colors = plt.cm.binary(np.linspace(0.2,1,num_plots))


df = pd.read_csv('../output/output_case3.csv'); #elasticity (0.5,0.5)

df1=df[(df['tax_sce']=='EP_hybrid') & (df['region_scenario']==2)] 
df1['Qeworld_chg']=-(df1['Qeworld_prime']-32.2760)/32.2760*100;
l1, = ax.plot(df1['welfare_noexternality'],df1['Qeworld_chg'],linestyle='solid', color = colors[0])
dot=df1[df1['varphi']==2] #puretp
ax.plot(dot['welfare_noexternality'],dot['Qeworld_chg'], marker='.', markersize=5, color='black', label='point')       
    
    ##EU/US
df2=df[(df['tax_sce']=='EP_hybrid') & (df['region_scenario']==7)] 
df2['Qeworld_chg']=-(df2['Qeworld_prime']-32.2760)/32.2760*100;
l2, = ax.plot(df2['welfare_noexternality'],df2['Qeworld_chg'],linestyle='dotted', color = colors[1])
dot=df2[df2['varphi']==2] #puretp
ax.plot(dot['welfare_noexternality'],dot['Qeworld_chg'], marker='.', markersize=5, color='black', label='point') 
       
    
    ##OECD
df3=df[(df['tax_sce']=='EP_hybrid')  & (df['region_scenario']==3)]
df3['Qeworld_chg']=-(df3['Qeworld_prime']-32.2760)/32.2760*100;
l3, = ax.plot(df3['welfare_noexternality'],df3['Qeworld_chg'],linestyle='dashed', color = colors[2])
dot=df3[df3['varphi']==2] #puretp
ax.plot(dot['welfare_noexternality'],dot['Qeworld_chg'], marker='.', markersize=5, color='black', label='point') 
       
    
    ##OECD/China
df4=df[(df['tax_sce']=='EP_hybrid') & (df['region_scenario']==6)]
df4['Qeworld_chg']=-(df4['Qeworld_prime']-32.2760)/32.2760*100;
l4, = ax.plot(df4['welfare_noexternality'],df4['Qeworld_chg'],linestyle='dashdot', color = colors[3])
dot=df4[df4['varphi']==2] #puretp
ax.plot(dot['welfare_noexternality'],dot['Qeworld_chg'], marker='.', markersize=5, color='black', label='point') 
       
    
    ##World
df5=df[(df['tax_sce']=='EP_hybrid') & (df['region_scenario']==4)] 
df5['Qeworld_chg']=-(df5['Qeworld_prime']-32.2760)/32.2760*100;
l5, = ax.plot(df5['welfare_noexternality'],df5['Qeworld_chg'],linestyle='dashed',dashes = (5,2), color = colors[4])
dot=df5[df5['varphi']==2] #puretp
ax.plot(dot['welfare_noexternality'],dot['Qeworld_chg'], marker='.', markersize=5, color='black', label='point') 


# ax.legend(handles = [l1,l2,l3,l4,l5] , labels=['EU', 'EU+US','OECD','OECD+China','World'],
#             loc='upper left', fancybox=True,bbox_to_anchor=(-0.075, -0.15) ,shadow=False, ncol=5,
#             frameon=False)

ax.legend(handles = [l1,l2,l3,l4,l5] , labels=['EU', 'EU+US','OECD','OECD+China','World'],
             loc='upper right', fancybox=True,shadow=False, ncol=1,
             frameon=False)
# 
ax.set_ylabel('Global emissions reductions (% of BAU)')
plt.axvline(x=-4,linestyle='dotted', color = 'gray', linewidth=0.75)


plt.savefig('../plots/LR_fig_8.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0.0)
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_5392/3501390410.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Qeworld_chg']=-(df1['Qeworld_prime']-32.2760)/32.2760*100;
# C:\Users\Alex\AppData\Local\Temp/ipykernel_5392/3501390410.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Qeworld_chg']=-(df2['Qeworld_prime']-32.2760)/32.2760*100;
# C:\Users\Alex\AppData\Local\Temp/ipykernel_5392/3501390410.py:33: SettingWithCopyWarning:
# ...

# %%
import PIL
import matplotlib.pyplot as plt
