# %%
import math
import numpy as np
import pandas as pd
from ces_utils import *
import warnings
warnings.filterwarnings('ignore')

# %%
# carbon content per unit of energy
h1 = 1

# elasticity parameters
sigma = 1
sigmaE = 1
theta = 4
rho = 0
alpha = 0.15

scenario = 'opt'

# elasticity of supply of renewables
epsilonSstar1 = 0.5
epsilonS1 = 0.5

# baseline, no renewable energy
epsilonSvec = [(epsilonS1, h1, 1)]
epsilonSstarvec = [(epsilonSstar1, h1, 1)]
assert(sum(k for i,j,k in epsilonSvec) == 1)
assert(sum(k for i,j,k in epsilonSstarvec) == 1)


data = pd.read_excel("../../raw_data/baselinecarbon_direct_2018.xlsx", index_col =0)
data['jxbar']=data['Cex']/(data['Cex'] + data['Ceystar'])
data['jmbar']=data['Cey']/(data['Cey'] + data['Cem'])

if scenario == 'constrained':
    data = data[(data['region_scenario'] == 3)] 
    tax_scenario= ['purete','puretc','puretp','EC_hybrid','EP_hybrid','PC_hybrid','EPC_hybrid']
elif scenario == 'global':
    data = data[(data['region_scenario'] == 3)] 
    tax_scenario= ['global']
elif scenario == 'opt':
    data = data[data['region_scenario'] != 4]
    tax_scenario= ['Unilateral']
data = data[(data['region_scenario'] == 3)] 
tax_scenario= ['purete','puretc','puretp','EC_hybrid','EP_hybrid','PC_hybrid','EPC_hybrid', 'global', 'Unilateral']
tax_scenario = ['Unilateral']

# %%
phi_list = np.arange(1,1.1,0.1)
model_parameters = (theta, sigma, sigmaE, epsilonSvec, epsilonSstarvec,rho, alpha)
temp = taxModel(data, tax_scenario, phi_list, model_parameters)

# %%
pe = 1
tb = 0
prop = 0
tax = 'Unilateral'
phi = 2
te = phi
for index, region_data in data.iterrows():
    res = temp.solveOne(phi, tax, region_data, pe, tb, prop, te)
res
# Out:
# (1.075273925304618, 0.8386089390677554, 0, 2)

# %%
temp.solve()

# %%
temp.res[0]['prices']
# Out:
# [(0.9866884097693971, 0.3875653831443224, 0, 1.0),
#  (0.9902307380438233, 0.42778213874612003, 0, 1.1)]

# %%
def iterate_tax(tax_scenario,df,theta, sigma, sigmaE, epsilonSvec, epsilonSstarvec):
    paralist = (theta, sigma, epsilonSvec, epsilonSstarvec)
    varphilist = np.arange(0,5,0.1)
    #varphilist = np.arange (0,1,0.2)
    #varphilist = [0,1]
    output=[]
    prevtb = []
    for varphi in varphilist:    
        tax_df=df.apply(iterate_region, axis=1, raw=False, args=(prevtb, varphi, tax_scenario, paralist))
        prevtb = tax_df[['region_scenario','tb', 'pe', 'te', 'prop']]
        output.append(tax_df)
        print(varphi)
        
    output = pd.concat(output, axis=0, join='outer',  ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False,copy=True)
    output.reset_index(level=0, inplace=True)
    output = output.sort_values(by=['region_scenario','varphi'])
    
    # if extraction tax too large home stops extracting
    if tax_scenario['tax_sce']=='purete' or tax_scenario['tax_sce']=='EP_hybrid' or tax_scenario['tax_sce'] == 'Unilateral':
        output.te[output.Qe_prime==0]=output.pe+output.tb
    print(tax_scenario['tax_sce'])
    return output

# %%
def iterate_region(df, prevtb, varphi, tax_scenario, paralist):
    # initial guess if previous value isn't available
    pe = 1
    te = 0.5
    tb_mat = [0,0.5]
    
    # use previous vector of solution if available
    if (type(prevtb) != list):
        curr_region = prevtb[prevtb['region_scenario'] == df['region_scenario']]
        vals = curr_region.values
        tb_mat = [vals[0][1], vals[0][4]]
        pe = vals[0][2]
        te = vals[0][3]
    tax_temp = tax_eq(pe, te, tb_mat, df, tax_scenario, varphi, paralist)
    tax_temp.opt_tax()
    ret = tax_temp.retrieve()
    return ret

# %%
res = tax_scenario.apply(iterate_tax, axis=1, args=(df,theta, sigma, sigmaE, epsilonSvec, epsilonSstarvec))
# Out:
# 0
# 1
# Unilateral

# %%
output_list=[]
for i in range(0,len(tax_scenario)):
    output_list.append(res.loc[i])
result = pd.concat(output_list, axis=0, join='outer', ignore_index=False, keys=tax_scenario['tax_sce'], levels=None, verify_integrity=False,copy=True)
result.reset_index(level=0, inplace=True)
result
# Out:
#        tax_sce              regionbase  varphi        pe        tb    prop  \
# 0   Unilateral              US as Home     0.0  1.000000  0.000000  0.5000
# 6   Unilateral              US as Home     1.0  0.982030  0.666520  0.0000
# 1   Unilateral            EU28 as Home     0.0  1.000000  0.000000  0.5000
# 7   Unilateral            EU28 as Home     1.0  0.982351  0.681389  0.0000
# 2   Unilateral          OECD37 as Home     0.0  1.000000  0.000000  0.5000
# 8   Unilateral          OECD37 as Home     1.0  0.943492  0.684949  0.0000
# 3   Unilateral           China as Home     0.0  1.000000  0.000000  0.5000
# 9   Unilateral           China as Home     1.0  0.964375  0.671944  1.0000
# 4   Unilateral  OECD and China as Home     0.0  1.000000  0.000000  0.5125
# 10  Unilateral  OECD and China as Home     1.0  0.880305  0.708559  0.0000
# 5   Unilateral       US and EU as Home     0.0  1.000000  0.000000  0.5000
# 11  Unilateral       US and EU as Home     1.0  0.961290  0.683898  1.0000
#
#      te  jxbar_prime  jmbar_prime  j0_prime  ...  delta_UCed  delta_UCedstar  \
# 0   0.0     0.018968     0.740153  0.018968  ...   -0.000000       -0.000000
# 6   1.0     0.020455     0.740153  0.013971  ...   -0.536938        0.065581
# 1   0.0     0.022199     0.643066  0.022199  ...   -0.000000       -0.000000
# 7   1.0     0.023999     0.643066  0.016280  ...   -0.456176        0.067569
# 2   0.0     0.057913     0.779597  0.057913  ...   -0.000000       -0.000000
# 8   1.0     0.062787     0.779597  0.042427  ...   -1.232322        0.125845
# 3   0.0     0.082553     0.907132  0.082553  ...   -0.000000       -0.000000
# 9   1.0     0.088849     0.907132  0.061491  ...   -0.248145        0.151876
# 4   0.0     0.148195     0.902934  0.148195  ...   -0.000000       -0.000000
# 10  1.0     0.161489     0.902934  0.108793  ...   -1.403459        0.211577
# 5   0.0     0.039156     0.727941  0.039156  ...   -0.000000       -0.000000
# 11  1.0     0.042408     0.727941  0.028674  ...   -0.980873        0.107404
#
#     leak  leakstar       welfare  welfare_noexternality  Qe1_prime  \
# 0    0.0       0.0 -0.000000e+00           0.000000e+00   4.711400
# 6    0.0       0.0  3.540702e+00          -2.718766e+00   3.794213
# 1    0.0       0.0 -0.000000e+00           0.000000e+00   0.865800
# 7    0.0       0.0  3.680509e+00          -2.677807e+00   0.705369
# 2    0.0       0.0 -1.898713e-14          -1.898713e-14   9.303970
# 8    0.0       0.0  3.481988e+00          -2.664672e+00   7.375657
# 3    0.0       0.0 -0.000000e+00           0.000000e+00   7.549100
# 9    0.0       0.0  3.330787e+00          -2.574428e+00   6.021886
# 4    0.0       0.0 -0.000000e+00           0.000000e+00  16.853070
# 10   0.0       0.0  3.272076e+00          -2.576136e+00  12.932625
# 5    0.0       0.0 -0.000000e+00           0.000000e+00   5.577200
# 11   0.0       0.0  3.565708e+00          -2.681471e+00   4.479807
#
#     Qe1star_prime  region_scenario  conv
# 0       28.923900              1.0   1.0
# 6       27.893724              1.0   1.0
# 1       32.769500              2.0   1.0
# 7       31.623000              2.0   1.0
# 2       24.331330              3.0   1.0
# 8       21.659196              3.0   1.0
# 3       26.086200              5.0   1.0
# 9       24.260669              5.0   1.0
# 4       16.782230              6.0   1.0
# 10      13.005179              6.0   1.0
# 5       28.058100              7.0   1.0
# 11      25.927867              7.0   1.0
#
# [12 rows x 53 columns]

# %%
result[['pe','tb', 'Ced_prime', 'Cedstar_prime', 'Cey_prime', 'Cex_prime', 'Cem_prime', 'Ceystar_prime', 'Vg_prime']]
# Out:
#           pe        tb  Ced_prime  Cedstar_prime  Cey_prime  Cex_prime  \
# 0   1.000000  0.000000   1.074100       3.616600   3.454000   0.460500
# 6   0.982030  0.666520   0.651542       3.682779   2.095174   0.306319
# 1   1.000000  0.000000   0.896100       3.794600   1.982700   0.574100
# 7   0.982351  0.681389   0.538606       3.862775   1.191713   0.379575
# 2   1.000000  0.000000   2.527200       2.163500   8.752300   1.026100
# 8   0.943492  0.684949   1.551913       2.293077   5.374648   0.695734
# 3   1.000000  0.000000   0.503900       4.186800   7.725500   1.686400
# 9   0.964375  0.671944   0.307947       4.341464   4.721268   1.127770
# 4   1.000000  0.000000   3.031100       1.659600  17.826800   1.363600
# 10  0.880305  0.708559   1.907715       1.885255  11.219837   0.954305
# 5   1.000000  0.000000   1.970200       2.720500   5.641400   0.829900
# 11  0.961290  0.683898   1.197553       2.830052   3.429031   0.556216
#
#     Cem_prime  Ceystar_prime    Vg_prime
# 0    1.212600      23.817500   31.110667
# 6    0.735555      24.216567   31.110667
# 1    1.100500      25.287300   20.554667
# 7    0.661462      25.694237   20.554667
# 2    2.474400      16.691800   74.844667
# 8    1.519490      17.599991   74.844667
# 3    0.790900      18.741800   56.776000
# 9    0.483341      19.300762   56.776000
# 4    1.916400       7.837800  131.621333
# 10   1.206144       8.764549  131.621333
# 5    2.108400      20.364900   51.665333
# 11   1.281556      21.113265   51.665333

# %%
#outcome_t = Outcomes[Outcomes['regionbase'] == 'US as Home']
result[['pe','tb','te','varphi', 'Qe_prime', 'Qeworld_prime','delta_Vg','delta_Vgstar','delta_Le','delta_Lestar','delta_UCed', 'delta_UCedstar','welfare','welfare_noexternality']]
# Out:
#           pe        tb   te  varphi   Qe_prime  Qeworld_prime  delta_Vg  \
# 0   1.000000  0.000000  0.0     0.0   4.711400      33.635300 -0.000000
# 6   0.982030  0.666520  1.0     1.0   3.794213      31.687938 -2.332815
# 1   1.000000  0.000000  0.0     0.0   0.865800      33.635300 -0.000000
# 7   0.982351  0.681389  1.0     1.0   0.705369      32.328369 -1.569558
# 2   1.000000  0.000000  0.0     0.0   9.303970      33.635300 -0.000000
# 8   0.943492  0.684949  1.0     1.0   7.375657      29.034853 -5.474401
# 3   1.000000  0.000000  0.0     0.0   7.549100      33.635300 -0.000000
# 9   0.964375  0.671944  1.0     1.0   6.021886      30.282555 -4.193893
# 4   1.000000  0.000000  0.0     0.0  16.853070      33.635300 -0.000000
# 10  0.880305  0.708559  1.0     1.0  12.932625      25.937805 -9.141488
# 5   1.000000  0.000000  0.0     0.0   5.577200      33.635300 -0.000000
# 11  0.961290  0.683898  1.0     1.0   4.479807      30.407674 -3.858273
#
#     delta_Vgstar  delta_Le  delta_Lestar  delta_UCed  delta_UCedstar  \
# 0      -0.000000  0.000000      0.000000   -0.000000       -0.000000
# 6       0.234678 -0.750221     -1.020948   -0.536938        0.065581
# 1      -0.000000  0.000000      0.000000   -0.000000       -0.000000
# 7       0.200392 -0.132539     -1.136412   -0.456176        0.067569
# 2      -0.000000  0.000000      0.000000   -0.000000       -0.000000
# 8       0.549121 -1.556267     -2.597367   -1.232322        0.125845
# 3      -0.000000  0.000000      0.000000   -0.000000       -0.000000
# 9      -0.031722 -1.239087     -1.793211   -0.248145        0.151876
# 4      -0.000000  0.000000      0.000000   -0.000000       -0.000000
# 10      0.479585 -3.079169     -3.555801   -1.403459        0.211577
# 5      -0.000000  0.000000      0.000000   -0.000000       -0.000000
# 11      0.453499 -0.895628     -2.089273   -0.980873        0.107404
#
#          welfare  welfare_noexternality
# 0  -0.000000e+00           0.000000e+00
# 6   3.540702e+00          -2.718766e+00
# 1  -0.000000e+00           0.000000e+00
# 7   3.680509e+00          -2.677807e+00
# 2  -1.898713e-14          -1.898713e-14
# 8   3.481988e+00          -2.664672e+00
# 3  -0.000000e+00           0.000000e+00
# 9   3.330787e+00          -2.574428e+00
# 4  -0.000000e+00           0.000000e+00
# 10  3.272076e+00          -2.576136e+00
# 5  -0.000000e+00           0.000000e+00
# 11  3.565708e+00          -2.681471e+00

# %%
result[['pe','tb','Lg_prime', 'Lgstar_prime']]
# Out:
#           pe        tb    Lg_prime  Lgstar_prime
# 0   1.000000  0.000000   22.182167    141.837233
# 6   0.982030  0.666520   22.434237    141.632663
# 1   1.000000  0.000000   14.488533    149.530867
# 7   0.982351  0.681389   14.813878    149.267116
# 2   1.000000  0.000000   55.410933    108.608467
# 8   0.943492  0.684949   56.016484    108.119158
# 3   1.000000  0.000000   53.334100    110.685300
# 9   0.964375  0.671944   54.235052    109.956419
# 4   1.000000  0.000000  108.745600     55.273800
# 10  0.880305  0.708559  109.610681     54.580648
# 5   1.000000  0.000000   36.670700    127.348700
# 11  0.961290  0.683898   37.153389    126.958059

# %%
name = 'direct_consumption_' + scenario + '.csv'
if epsilonSstar1 == 2:
    name = 'direct_consumption_higheps_' + scenario + '.csv'
result.to_csv('../../output/' + name, header=True)
name
# Out:
# 'direct_consumption_higheps_opt.csv'
