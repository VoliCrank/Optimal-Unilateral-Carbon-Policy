# %%
import math
import numpy as np
import pandas as pd
from ces_utils import *
import warnings
warnings.filterwarnings('ignore')
output_root = '../../output/'

# %%
# carbon content per unit of energy
h1 = 1

# elasticity parameters
sigma = 1
sigmaE = 1
theta = 4
rho = 0
alpha = 0.15

scenario = 'opt'

# elasticity of supply of renewables
epsilonSstar1 = 0.5
epsilonS1 = 0.5

# baseline, no renewable energy
epsilonSvec = [(epsilonS1, h1, 1)]
epsilonSstarvec = [(epsilonSstar1, h1, 1)]
assert(sum(k for i,j,k in epsilonSvec) == 1)
assert(sum(k for i,j,k in epsilonSstarvec) == 1)


data = pd.read_excel("../../raw_data/baselinecarbon_direct_2018.xlsx")
data['jxbar']=data['Cex']/(data['Cex'] + data['Ceystar'])
data['jmbar']=data['Cey']/(data['Cey'] + data['Cem'])

if scenario == 'constrained':
    data = data[(data['region_scenario'] == 3)] 
    tax_scenario= ['purete','puretc','puretp','EC_hybrid','EP_hybrid','PC_hybrid','EPC_hybrid']
elif scenario == 'global':
    data = data[(data['region_scenario'] == 3)] 
    tax_scenario= ['global']
elif scenario == 'opt':
    data = data[data['region_scenario'] != 4]
    tax_scenario= ['Unilateral']
#tax_scenario = ['Unilateral']

# %%
phi_list = np.arange(0,5,0.1)
model_parameters = (theta, sigma, sigmaE, epsilonSvec, epsilonSstarvec, rho, alpha)
model = taxModel(data, tax_scenario, phi_list, model_parameters)

# %%
model.solve()
# Out:
# Unilateral
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9
# 1.0
# 1.1
# 1.2000000000000002
# 1.3
# 1.4000000000000001
# 1.5
# 1.6
# 1.7000000000000002
# 1.8
# 1.9000000000000001
# 2.0
# 2.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10884/2771836399.py in <module>
# ----> 1 model.solve()
#
# ~\Desktop\Tobin\sam\Optimal-Unilateral-Carbon-Policy\simulation_results\codes\direct_energy_consumption\ces_utils.py in solve(self, pe_guess, tb_guess, prop_guess, te_guess)
#      29                 for phi in self.phi_list:
#      30                     # solve model for given phi, tax scenario, region, and guesses for pe, tb, and prop
# ---> 31                     price = self.solveOne(phi, tax, region_data, pe_prev, tb_prev, prop_prev, te_prev)
#      32                     # set new guess to result of previous simulation
#      33                     pe_prev, tb_prev, prop_prev, te_prev = price
#
# ~\Desktop\Tobin\sam\Optimal-Unilateral-Carbon-Policy\simulation_results\codes\direct_energy_consumption\ces_utils.py in solveOne(self, phi, tax, region_data, pe, tb, prop, te)
#      83         elif tax in ['Unilateral', 'puretc', 'puretp', 'EC_hybrid']:
#      84             props = [prop]
# ---> 85             opt_val = self.min_obj(props, tbs, pes, phi, tax, region_data)
#      86
#      87             tb = opt_val[1]
#
# ~\Desktop\Tobin\sam\Optimal-Unilateral-Carbon-Policy\simulation_results\codes\direct_energy_consumption\ces_utils.py in min_obj(self, props, tbs, pes, phi, tax, region_data, bounds)
#     108             for tb in tbs:
#     109                 for pe in pes:
# --> 110                     res = minimize(self.find_eq, [pe, tb, prop], bounds=bounds, args=(phi, tax, region_data),
#     111                                    method='nelder-mead', tol=0.000001, options={'maxfev': 100000})
#     112                     if res.fun <= 0.0001:
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     609
#     610     if meth == 'nelder-mead':
# --> 611         return _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     612                                     **options)
#     613     elif meth == 'powell':
#
# ~\AppData\Roaming\Python\Python39\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     820         ind = np.argsort(fsim)
#     821         sim = np.take(sim, ind, 0)
# --> 822         fsim = np.take(fsim, ind, 0)
#     823         if callback is not None:
#     824             callback(sim[0])
#
# <__array_function__ internals> in take(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py in take(a, indices, axis, out, mode)
#     188            [5, 7]])
#     189     """
# --> 190     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     191
#     192
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
df = model.retrieve()

# %%
name = 'direct_consumption_' + scenario + '.csv'
if epsilonSstar1 == 2:
    name = output_root + 'direct_consumption_higheps_' + scenario + '.csv'

name = output_root + 'temp.csv'
print(name)
model.retrieve(name)
# Out:
# ../../output/temp.csv
#                 region     tax_sce  varphi        pe        tb  prop   te  \
# 0           US as Home  Unilateral     0.0  1.000000  0.000000   0.0  0.0
# 1           US as Home  Unilateral     0.1  0.999008  0.034485   0.0  0.1
# 2           US as Home  Unilateral     0.2  0.998393  0.068927   0.0  0.2
# 3           US as Home  Unilateral     0.3  0.998142  0.103365   0.0  0.3
# 4           US as Home  Unilateral     0.4  0.998249  0.137835   0.0  0.4
# ..                 ...         ...     ...       ...       ...   ...  ...
# 295  US and EU as Home  Unilateral     4.5  0.970376  1.664303   0.0  4.5
# 296  US and EU as Home  Unilateral     4.6  0.968885  1.699247   0.0  4.6
# 297  US and EU as Home  Unilateral     4.7  0.967426  1.734158   0.0  4.7
# 298  US and EU as Home  Unilateral     4.8  0.965996  1.769039   0.0  4.8
# 299  US and EU as Home  Unilateral     4.9  0.964594  1.803889   0.0  4.9
#
#      jxbar_prime  jmbar_prime  j0_prime  ...  delta_Vg  delta_Vgstar  \
# 0       0.018968     0.740153  0.018968  ... -0.000000     -0.000000
# 1       0.018973     0.740153  0.018593  ... -0.153737      0.008617
# 2       0.018989     0.740153  0.018237  ... -0.304033      0.008898
# 3       0.019015     0.740153  0.017898  ... -0.451162      0.001062
# 4       0.019050     0.740153  0.017576  ... -0.595396     -0.014793
# ..           ...          ...       ...  ...       ...           ...
# 295     0.052960     0.727941  0.021891  ... -7.507707      0.008257
# 296     0.053461     0.727941  0.021710  ... -7.605489      0.034301
# 297     0.053968     0.727941  0.021532  ... -7.702048      0.059854
# 298     0.054481     0.727941  0.021359  ... -7.797415      0.084940
# 299     0.055002     0.727941  0.021189  ... -7.891617      0.109579
#
#      delta_UCed  delta_UCedstar  leak  leakstar    welfare  \
# 0     -0.000000       -0.000000   0.0       0.0  -0.000000
# 1     -0.035385        0.003588   0.0       0.0   0.027943
# 2     -0.069978        0.005816   0.0       0.0   0.111616
# 3     -0.103843        0.006725   0.0       0.0   0.250989
# 4     -0.137041        0.006339   0.0       0.0   0.446202
# ..          ...             ...   ...       ...        ...
# 295   -1.908654        0.081810   0.0       0.0  37.545194
# 296   -1.933512        0.085992   0.0       0.0  38.707795
# 297   -1.958060        0.090094   0.0       0.0  39.874464
# 298   -1.982305        0.094118   0.0       0.0  41.045120
# 299   -2.006254        0.098068   0.0       0.0  42.219696
#
#      welfare_noexternality  Qe1_prime  Qe1star_prime
# 0                 0.000000   4.711400      28.923900
# 1                -0.027894   4.552034      28.909554
# 2                -0.111408   4.387727      28.900651
# 3                -0.250745   4.217971      28.897019
# 4                -0.446841   4.042160      28.898561
# ..                     ...        ...            ...
# 295             -14.678692   0.000000      27.639379
# 296             -14.865709   0.000000      27.618142
# 297             -15.053001   0.000000      27.597330
# 298             -15.240573   0.000000      27.576927
# 299             -15.428424   0.000000      27.556914
#
# [300 rows x 51 columns]
