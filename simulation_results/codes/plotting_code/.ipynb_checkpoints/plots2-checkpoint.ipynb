# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter
import matplotlib.font_manager as fm
import palettable

# %%
mpl.__version__
mpl.rcParams.update({'font.size': 7})
mpl.rcParams['axes.grid'] = True
mpl.rcParams.update({'axes.grid.axis':'y','grid.color':'#949494','grid.linewidth':0.2})
plt.locator_params(axis='y', nbins=5)   # y-axis

# %%
df = pd.read_csv('../../output/direct_consumption.csv')

# %%
df
# Out:
#       Unnamed: 0     tax_sce      regionbase        pe         tb  region  \
# 0              0  Unilateral  OECD37 as Home  1.000000   0.000000     3.0
# 1              6  Unilateral  OECD37 as Home  0.993667   0.039981     3.0
# 2             12  Unilateral  OECD37 as Home  0.988369   0.079572     3.0
# 3             18  Unilateral  OECD37 as Home  0.984046   0.118887     3.0
# 4             24  Unilateral  OECD37 as Home  0.980653   0.158018     3.0
# ...          ...         ...             ...       ...        ...     ...
# 3595        3575  Unilateral      80% C Home  0.007685  35.047120    12.0
# 3596        3581  Unilateral      80% C Home  0.007667  35.099024    12.0
# 3597        3587  Unilateral      80% C Home  0.007648  35.151213    12.0
# 3598        3593  Unilateral      80% C Home  0.007629  35.202903    12.0
# 3599        3599  Unilateral      80% C Home  0.007611  35.254797    12.0
#
#       varphi  jxbar_prime  jmbar_prime  j0_prime  ...  leakage2  leakage3  \
# 0        0.0     0.049234     0.819498  0.049234  ...  0.033333  0.323333
# 1        0.1     0.049253     0.819498  0.048138  ...  0.084004  0.225309
# 2        0.2     0.049307     0.819498  0.047105  ...  0.065028  0.204957
# 3        0.3     0.049394     0.819498  0.046128  ...  0.045979  0.184435
# 4        0.4     0.049511     0.819498  0.045204  ...  0.026879  0.163754
# ...      ...          ...          ...       ...  ...       ...       ...
# 3595    59.5     1.000000     0.544095  0.002799  ... -0.499997 -0.126238
# 3596    59.6     1.000000     0.544095  0.002792  ... -0.499987 -0.126249
# 3597    59.7     1.000000     0.544095  0.002786  ... -0.499976 -0.126260
# 3598    59.8     1.000000     0.544095  0.002779  ... -0.499966 -0.126271
# 3599    59.9     1.000000     0.544095  0.002773  ... -0.499955 -0.126282
#
#       chg_extraction  chg_production  chg_consumption  chg_Qeworld  \
# 0           0.000000    1.000000e-07     9.700000e-07    -0.000003
# 1          -0.075012    3.075279e-02     8.248284e-02    -0.366088
# 2          -0.137945    4.731719e-02     1.491358e-01    -0.727645
# 3          -0.189416    4.992940e-02     2.002801e-01    -1.085909
# 4          -0.229903    3.876288e-02     2.361562e-01    -1.442139
# ...              ...             ...              ...          ...
# 3595      -14.713900   -1.543099e+01    -3.895990e+00   -30.862145
# 3596      -14.715629   -1.543153e+01    -3.896544e+00   -30.863874
# 3597      -14.717337   -1.543206e+01    -3.897102e+00   -30.865582
# 3598      -14.719064   -1.543259e+01    -3.897649e+00   -30.867309
# 3599      -14.720776   -1.543312e+01    -3.898199e+00   -30.869021
#
#            pai_g  subsidy_ratio       welfare  welfare_noexternality
# 0       0.000000       0.000000 -4.317474e-07          -4.317474e-07
# 1      -0.204258       0.005999  1.992536e-02          -1.992110e-02
# 2      -0.412435       0.011932  7.957643e-02          -7.882309e-02
# 3      -0.624856       0.017800  1.782903e-01          -1.762933e-01
# 4      -0.841802       0.023600  3.158152e-01          -3.120568e-01
# ...          ...            ...           ...                    ...
# 3595 -313.531245       0.998540  9.022444e+02          -9.006285e+01
# 3596 -314.008933       0.998546  9.039123e+02          -9.011839e+01
# 3597 -314.489249       0.998552  9.055797e+02          -9.017391e+01
# 3598 -314.964965       0.998557  9.072481e+02          -9.022925e+01
# 3599 -315.442571       0.998563  9.089162e+02          -9.028458e+01
#
# [3600 rows x 46 columns]

# %%
def plot_tax(fig, lodf, xlow = -35, xhigh = 0, ylow = 0, yhigh = 40, varphi = 20, x = 'welfare_noexternality', y = 'Qeworld_chg'):
    i=0
    for ax in fig.get_axes():
        ax.set_xlim(xlow,xhigh)
        ax.set_ylim(ylow,yhigh)
        ax.spines["top"].set_visible(False)    
        ax.spines["bottom"].set_visible(True)    
        ax.spines["right"].set_visible(False)    
        ax.spines["left"].set_visible(False)
        
        df = lodf[i]
        i += 1

        df = df[df['varphi'] <= varphi]
        df_opt = df[(df['tax_sce']=='Unilateral') & (df['region_scenario']==3)] 
        df_opt['Qeworld_chg']=-(df_opt['Qeworld_prime']-df_opt['Qeworld_prime'].iat[0]) / df_opt['Qeworld_prime'].iat[0]
        #df['Qeworld_chg']=-(df['Qeworld_prime']-Qeworld)/Qeworld*100
        #x = 'varphi'
        #y = 'ratio'

        ##puretp
        df_plot=df[(df['tax_sce']=='puretp') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0])/df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l1, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed',dashes = (5,1), label = 'production tax')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##purete
        df_plot=df[(df['tax_sce']=='purete') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0])/ df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l2, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed',dashes = (8,1), label = 'extraction tax')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##puretc
        df_plot=df[(df['tax_sce']=='puretc') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l3, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed',dashes = (5,3), label = 'consumption tax')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##production/consumption
        df_plot=df[(df['tax_sce']=='PC_hybrid') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l4, = ax.plot(df_plot[x],df_plot[y],linestyle='dotted', label = 'production-consumption')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##extracion/production
        df_plot=df[(df['tax_sce']=='EP_hybrid')  & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l5, = ax.plot(df_plot[x],df_plot[y],linestyle='dashed', label = 'extraction-production')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        # #extraction/consumption
        df_plot=df[(df['tax_sce']=='EC_hybrid') & (df['region_scenario']==3)]
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l6, = ax.plot(df_plot[x],df_plot[y],linestyle='dashdot', label = 'extraction-consumption')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        # #extraction/consumption/production
        df_plot=df[(df['tax_sce']=='EPC_hybrid') & (df['region_scenario']==3)]
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l8, = ax.plot(df_plot[x],df_plot[y],linestyle='dashdot', label = 'extraction-cons-prod')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red') 

        ##unilateral optimal
        df_plot=df[(df['tax_sce']=='Unilateral') & (df['region_scenario']==3)] 
        df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
        df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
        l7, = ax.plot(df_plot[x],df_plot[y],linestyle='solid', label = 'unilateral optimal')
        dot=df_plot[df_plot['varphi']==2] #puretp
        ax.plot(dot[x],dot[y], marker='x', markersize=3, color='red')

# %%
fig, (ax1) = plt.subplots(1, 1)   
#ax2.plot(df4['welfare_noexternality'], df4['Qeworld_chg'], linestyle = 'solid', label = 'global planner', color = "purple")

plot_tax(fig, [df], xlow = -12, xhigh =0, yhigh = 30, varphi = 20)
ylab = 'Global emissions reductions (% of BAU)'
xlab = 'Change in total consumption \n(% of initial goods consumption)'
#ylab = 'Global emissions reduction (% of BAU)'
#xlab = 'varphi'
ax1.set_ylabel(ylab)
ax1.set_xlabel(xlab)

ax1.legend(loc='upper left', bbox_to_anchor=(0, -0.2),fancybox=True, shadow=False, ncol=4, frameon=False)
plt.savefig('../../plots/direct_fig4.pdf', format='PDF', bbox_inches='tight')
# Out:
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opt['Qeworld_chg']=-(df_opt['Qeworld_prime']-df_opt['Qeworld_prime'].iat[0]) / df_opt['Qeworld_prime'].iat[0]
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0])/df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:24: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0])/ df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:32: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:40: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:48: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:56: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:64: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:72: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['Qeworld_chg']=-(df_plot['Qeworld_prime']-df_plot['Qeworld_prime'].iat[0]) / df_plot['Qeworld_prime'].iat[0] * 100
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:80: RuntimeWarning: invalid value encountered in true_divide
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])
# C:\Users\Alex\AppData\Local\Temp/ipykernel_1632/1775008261.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ratio'] = np.array(df_plot['Qeworld_chg']) / np.array(df_opt['Qeworld_chg'])

# %%
plot = plot_all(df, 'varphi', 'tb')
plot.ylabel('tb')
plot.xlabel('varphi')
plot.xlim(0,30)
plot.savefig('../plots/phi_tb.pdf', format='PDF')

# %%
plt.xlim(0,60)
df1=df[(df['tax_sce']=='Unilateral') & (df['region']==2)] 
l1, = plt.plot(df1['varphi'],df1['pe'],linestyle='dashed',dashes = (5,2),label = 'EU')
        
    
##EU/US
df2=df[(df['tax_sce']=='Unilateral') & (df['region']==7)] 
l2, = plt.plot(df2['varphi'],df2['pe'],linestyle='dashed',dashes = (5,2), label = 'EU and US')
       
    
##OECD
df3=df[(df['tax_sce']=='Unilateral')  & (df['region']==3)]
l3, = plt.plot(df3['varphi'],df3['pe'],linestyle='dashed', dashes = (5,2),label = 'OECD')
       
    
##OECD/China
df4=df[(df['tax_sce']=='Unilateral') & (df['region']==6)]
l4, = plt.plot(df4['varphi'],df4['pe'],linestyle='dashed',dashes = (5,2), label = 'OECD and China')
       
    
##World
df5=df[(df['tax_sce']=='Unilateral') & (df['region']==4)] 
l5, = plt.plot(df5['varphi'],df5['pe'],linestyle='dashed',dashes = (5,2), label = 'World')

## US
df6=df[(df['tax_sce']=='Unilateral') & (df['region']==1)] 
l6, = plt.plot(df6['varphi'],df6['pe'],linestyle='dashed',dashes = (5,2), label = 'US')

# China
df7=df[(df['tax_sce']=='Unilateral') & (df['region']==5)] 
plt.plot(df7['varphi'],df7['pe'],linestyle='dashed',dashes = (5,2), label = 'China')

plt.legend()
plt.savefig('../plots/phi_pe.pdf', format='PDF')

# %%
def plot_all(x, y, df):
    plt.xlim(0,60)
    df1=df[(df['tax_sce']=='Unilateral') & (df['region']==2)] 
    #l1, = plt.plot(df1[x],df1[y],linestyle='dashed',dashes = (5,2),label = 'EU')
        
    
    ##EU/US
    df2=df[(df['tax_sce']=='Unilateral') & (df['region']==7)] 
    l2, = plt.plot(df2[x],df2[y],linestyle='dashed',dashes = (5,2), label = 'EU and US')
       
    
    ##OECD
    df3=df[(df['tax_sce']=='Unilateral')  & (df['region']==3)]
    l3, = plt.plot(df3[x],df3[y],linestyle='dashed', dashes = (5,2),label = 'OECD')
       
    
    ##OECD/China
    df4=df[(df['tax_sce']=='Unilateral') & (df['region']==6)]
    l4, = plt.plot(df4[x],df4[y],linestyle='dashed',dashes = (5,2), label = 'OECD and China')
       
    
    ##World
    #df5=df[(df['tax_sce']=='Unilateral') & (df['region']==4)] 
    #l5, = plt.plot(df5[x],df5[y],linestyle='dashed',dashes = (5,2), label = 'World')

    ## US
    df6=df[(df['tax_sce']=='Unilateral') & (df['region']==1)] 
    #l6, = plt.plot(df6[x],df6[y],linestyle='dashed',dashes = (5,2), label = 'US')

    # China
    df7=df[(df['tax_sce']=='Unilateral') & (df['region']==5)] 
    plt.plot(df7[x],df7[y],linestyle='dashed',dashes = (5,2), label = 'China')
    
    df8=df[(df['tax_sce']=='Unilateral') & (df['region']==8)] 
    plt.plot(df8[x],df8[y],linestyle='dashed',dashes = (5,2), label = '80% World')
    
    df8=df[(df['tax_sce']=='Unilateral') & (df['region']==9)] 
    plt.plot(df8[x],df8[y],linestyle='dashed',dashes = (5,2), label = '90% World')
    
    df8=df[(df['tax_sce']=='Unilateral') & (df['region']==10)] 
    plt.plot(df8[x],df8[y],linestyle='dashed',dashes = (5,2), label = '90% World Small Ge')

    plt.legend()
    return plt
#plt.savefig('../plots/phi_pe.pdf', format='PDF')

# %%
plot = plot_all('varphi', 'jxbar_prime', df)
plt.ylabel('jxbar_prime')
plt.xlabel('varphi')
plot.savefig('../plots/phi_jxbar.pdf', format='PDF')

# %%
plot = plot_all('varphi', 'pe', df)
plt.ylabel('pe')
plt.xlabel('varphi')
plot.savefig('../plots/phi_pe.pdf', format='PDF')

# %%
df8=df[(df['tax_sce']=='Unilateral') & (df['region']==10)] 
plt.plot(df8['varphi'],df8['jxbar_prime'],linestyle='dashed',dashes = (5,2), label = '90% World')

# %%
plt.plot(df1['varphi'],df1['chg_production'], color='C0',linewidth=1)

# %%
plt.xlim(0,50)
plt.plot(df1['varphi'],df1['Lg_prime'], color='C0',linewidth=1)
plt.plot(df1['varphi'],df1['Lgstar_prime'], color='C0',linewidth=1)

# %%
#plt.xlim(0,50)
plt.plot(df1['pe'],df1['Vg_prime'], color='C0',linewidth=1)
#plt.plot(df1['varphi'],df1['Vgstar_prime'], color='C0',linewidth=1)
